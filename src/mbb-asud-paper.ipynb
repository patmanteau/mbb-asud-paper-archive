# %% [markdown]
# ## Tagebuch
#
# ### 2023-06-25
#
# Motivierende Idee:
# - Einen Graph aus Personen/Orten bauen, die in Tagesschau-Artikeln gemeinsam erwähnt wurden
# - Eventuell nach Entfernung der Erwähnung gewichten
# - Lustige Netzwerkanalysen im Graph durchführen
# - Visualisieren!
#
# #### Erster Ansatz
#
# spaCy anwerfen und NER betreiben!

# %% [markdown]
# ## Aufbauen des Datenkorpus
#
# ### Step 0: Einrichten der Umgebung

# %%
import json
import pandas as pd
from pathlib import Path
import spacy
from tqdm import tqdm

# Path to the root of the project
_bd = (Path(".") / "..").resolve()

# Data directory
_dd  = _bd / "data"

# %% [markdown]
# ### Step 1: Sammeln von Nachrichtenartikeln
#
# Artikel von [Tagesschau](https://www.tagesschau.de/) sammeln. Scraping mit [Scrapy](https://scrapy.org/):
#
# ```bash
# cd newsscrape
# scrapy crawl tagesspider -O ../data/tagesschau.jsonl
# ```

# %% [markdown]
# Einen Blick auf die Daten werfen:

# %%
df_texts = pd.read_json(open(f"{_dd}/tagesschau.jsonl", "r", encoding="utf8"), lines=True)
print(df_texts.shape)
df_texts.sample(5)
# Out:
# (15123, 6)
#           tstamp                                    title  \
# 4729  1666153084            Wie Heimkinder sediert werden
# 7825  1671537213  Gericht in Italien erlaubt Auslieferung
# 94    1657703376                     Wer entscheidet über
# 592   1656911615                              "Kann keine
# 2251  1662043555         Herzog nimmt an Gedenkfeier teil
#
#                         date  \
# 4729  19.10.2022 • 06:18 Uhr
# 7825  20.12.2022 • 12:53 Uhr
# 94    13.07.2022 • 11:09 Uhr
# 592   04.07.2022 • 07:13 Uhr
# 2251  01.09.2022 • 16:45 Uhr
#
#                                               shorttext  \
# 4729  "Du wurdest mit Tabletten ruhiggestellt" - so ...
# 7825  Die Ehefrau eines ehemaligen Europaabgeordnete...
# 94    Wenn es um Waffenexporte geht, ist eigentlich ...
# 592   Im September läuft die Rechtsgrundlage für die...
# 2251  Israels Präsident Herzog nimmt bei seinem Staa...
#
#                                                     url  \
# 4729  /investigativ/br-recherche/sedierung-heimkinde...
# 7825  /ausland/europa/eu-korruptionsskandal-gericht-...
# 94    /inland/innenpolitik/bundessicherheitsrat-101....
# 592             /inland/coronavirus-lauterbach-103.html
# 2251  /ausland/asien/gedenkfeier-muenchen-praesident...
#
#                                                fulltext
# 4729   "Du wurdest mit Tabletten ruhiggestellt" - so...
# 7825   Die Ehefrau eines ehemaligen Europaabgeordnet...
# 94     Wenn es um Waffenexporte geht, ist eigentlich...
# 592    Im September läuft die Rechtsgrundlage für di...
# 2251   Israels Präsident Herzog nimmt bei seinem Sta...

# %% [markdown]
# ## Step 2: Extrahieren von Named Entities
#
# Spacy vorbereiten. Wir verwenden das größte deutsche Modell.
#
# Herausforderung I: Der erste Anlauf mit Spacys Standard-NER ergibt leider kein gutes Resultat. Spacy erkennt zwar Entitäten und ordnet sie auch häufig richtig zu, löst aber keine Ambiguitäten auf. "Obama", "Barack Obama", "Barack Hussein Obama" und "Präsident Obama" werden als vier verschiedene Entitäten erkannt. Das ist für unsere Zwecke nicht hilfreich.
#
# Lösungsansatz: Wir verwenden ein NER-Modell, das *Entity Disambiguation* bzw. *Entity Linking* unterstützt: @sw-entity-fishing, das per @sw-spacyfishing in Spacy integriert werden kann.

# %%
nlp = spacy.load("de_core_news_lg")
nlp.add_pipe("entityfishing", config={"language": "de"})

# %%
def extract_persons(ents):
    persons = {}
    for ent in ents:
        if ent.label_:
            if ent._.kb_qid:
                persons[ent._.kb_qid] = (
                    ent.text,
                    ent.label_,
                    ent._.kb_qid,
                    ent._.url_wikidata,
                    ent._.nerd_score,
                )
    return persons

# %%
doc = nlp(df_texts.sample(1)["fulltext"].values[0])
print(json.dumps(extract_persons(doc.ents), indent=4))
# print(json.dumps(extract_persons(doc.ents)))
doc
# Out:
# {
#     "Q46970": [
#         "Airlines",
#         "ORG",
#         "Q46970",
#         "https://www.wikidata.org/wiki/Q46970"
#     ],
#     "Q2514275": [
#         "Verbraucherzentrale NRW",
#         "ORG",
#         "Q2514275",
#         "https://www.wikidata.org/wiki/Q2514275"
#     ],
#     "Q819697": [
#         "Handelsblatt",
#         "MISC",
#         "Q819697",
#         "https://www.wikidata.org/wiki/Q819697"
#     ],
#     "Q49768": [
#         "SPD",
#         "ORG",
#         "Q49768",
#         "https://www.wikidata.org/wiki/Q49768"
#     ],
#     "Q49762": [
#         "CDU",
#         "ORG",
#         "Q49762",
#         "https://www.wikidata.org/wiki/Q49762"
#     ],
#     "Q1197": [
#         "nieders\u00e4chsischen",
#         "MISC",
#         "Q1197",
#         "https://www.wikidata.org/wiki/Q1197"
#     ],
#     "Q1502854": [
#         "Steffi Lemke",
#         "PER",
#         "Q1502854",
#         "https://www.wikidata.org/wiki/Q1502854"
#     ],
#     "Q49766": [
#         "Gr\u00fcne",
#         "ORG",
#         "Q49766",
#         "https://www.wikidata.org/wiki/Q49766"
#     ],
#     "Q687323": [
#         "BGH-Urteil",
#         "MISC",
#         "Q687323",
#         "https://www.wikidata.org/wiki/Q687323"
#     ],
#     "Q15854651": [
#         "Jahr 2016",
#         "MISC",
#         "Q15854651",
#         "https://www.wikidata.org/wiki/Q15854651"
#     ],
#     "Q1006696": [
#         "Bundesrichter",
#         "LOC",
#         "Q1006696",
#         "https://www.wikidata.org/wiki/Q1006696"
#     ],
#     "Q157142": [
#         "Zeit",
#         "MISC",
#         "Q157142",
#         "https://www.wikidata.org/wiki/Q157142"
#     ],
#     "Q156829": [
#         "Air Berlin",
#         "ORG",
#         "Q156829",
#         "https://www.wikidata.org/wiki/Q156829"
#     ],
#     "Q9325": [
#         "Lufthansa",
#         "ORG",
#         "Q9325",
#         "https://www.wikidata.org/wiki/Q9325"
#     ],
#     "Q284657": [
#         "Jets",
#         "ORG",
#         "Q284657",
#         "https://www.wikidata.org/wiki/Q284657"
#     ],
#     "Q1726": [
#         "M\u00fcnchen",
#         "LOC",
#         "Q1726",
#         "https://www.wikidata.org/wiki/Q1726"
#     ],
#     "Q46033": [
#         "Frankfurt",
#         "LOC",
#         "Q46033",
#         "https://www.wikidata.org/wiki/Q46033"
#     ],
#     "Q58226": [
#         "D\u00fcsseldorf",
#         "LOC",
#         "Q58226",
#         "https://www.wikidata.org/wiki/Q58226"
#     ],
#     "Q2239626": [
#         "S\u00d6P",
#         "MISC",
#         "Q2239626",
#         "https://www.wikidata.org/wiki/Q2239626"
#     ],
#     "Q1009043": [
#         "BDL",
#         "ORG",
#         "Q1009043",
#         "https://www.wikidata.org/wiki/Q1009043"
#     ],
#     "Q1910442": [
#         "Matthias von Randow",
#         "PER",
#         "Q1910442",
#         "https://www.wikidata.org/wiki/Q1910442"
#     ],
#     "Q491637": [
#         "Bundesverkehrsministerium",
#         "ORG",
#         "Q491637",
#         "https://www.wikidata.org/wiki/Q491637"
#     ],
#     "Q1278715": [
#         "Volker Wissing",
#         "PER",
#         "Q1278715",
#         "https://www.wikidata.org/wiki/Q1278715"
#     ],
#     "Q13124": [
#         "FDP",
#         "ORG",
#         "Q13124",
#         "https://www.wikidata.org/wiki/Q13124"
#     ],
#     "Q319676": [
#         "Wettbewerbsnachteilen",
#         "MISC",
#         "Q319676",
#         "https://www.wikidata.org/wiki/Q319676"
#     ],
#     "Q1806351": [
#         "Lars Watermann",
#         "PER",
#         "Q1806351",
#         "https://www.wikidata.org/wiki/Q1806351"
#     ],
#     "Q213": [
#         "Tschechien",
#         "LOC",
#         "Q213",
#         "https://www.wikidata.org/wiki/Q213"
#     ],
#     "Q8896": [
#         "Rat der Europ\u00e4ischen Union",
#         "MISC",
#         "Q8896",
#         "https://www.wikidata.org/wiki/Q8896"
#     ],
#     "Q8880": [
#         "EU-Kommission",
#         "ORG",
#         "Q8880",
#         "https://www.wikidata.org/wiki/Q8880"
#     ]
# }
#  Flugreisende müssen schon bei der Buchung den vollen Ticketpreis zahlen. Verbraucherschützer machen sich angesichts chaotischer Zustände in der Branche dafür stark, das zu ändern. Die Airlines halten dagegen.  Verbraucherschützer fordern ein Ende der Praxis, dass Flugpassagiere schon bei Buchung ihrer Reise den vollen Ticketpreis bezahlen müssen. "Passagiere sind es leid, den Airlines zinslose Kredite zu geben, bei abgesagten Flügen auf den Kosten sitzen zu bleiben oder im schlimmsten Fall das Risiko einer Insolvenz tragen zu müssen", sagte Marion Jungbluth vom Bundesverband der Verbraucherzentralen (VZBV) dem "Handelsblatt". Von der Bundesregierung verlange man, die Vorkassepraxis zu reformieren. Gezahlt werden solle künftig erst beim Check-in. Auch das von SPD und CDU regierte Land Niedersachsen hat sich mit einer Bundesratsinitiative den Vorstoß der VZBV zu eigen gemacht. Unterstützung hat zudem das grün geführte Bundesministerium für Umwelt und Verbraucherschutz signalisiert. Die Fluggesellschaften seien in der Pflicht, bei berechtigten Ansprüchen Erstattungen, Ausgleichszahlungen und Entschädigungen schnell und unbürokratisch zu leisten, sagte gestern ein Sprecher der Verbraucherschutzministerin Steffi Lemke (Grüne). Es gehe darum, die Verbraucherrechte zu stärken. Der Anstieg von Beschwerden bei der Schlichtungsstelle könnte darauf hindeuten, dass dies derzeit nicht ganz reibungslos verlaufe. Wenn dies keine gute Entwicklung nehme, werde das Ministerium die Vorkasse-Praxis überprüfen. Allerdings existieren bereits drei Urteile des Bundesgerichtshofs, der noch im Jahr 2016 das Vorkasseprinzip der Airlines für rechtmäßig erklärt hat. Die Verbraucher seien durch die EU-Fluggastverordnung ausreichend geschützt und das Insolvenzrisiko durch staatliche Kontrolle in Grenzen gehalten, befanden die Bundesrichter. Mögliche Zinsnachteile der Kunden würden regelmäßig durch Preisvorteile bei frühen Buchungen ausgeglichen. Seitdem haben sich die Zeiten aber geändert, meinen die Verbraucherschützer, die nun auf eine Gesetzesänderung dringen: Nur kurze Zeit nach dem BGH-Urteil blieben Tausende Kunden der insolventen Air Berlin bis auf Weiteres auf ihren Ticketkosten sitzen. Es folgten der Chaos-Sommer 2018 und schließlich der Corona-Schock im März 2020. Hunderttausende Tickets wurden von jetzt auf gleich storniert, der Lufthansa-Konzern schaltete die automatisierte Erstattung ab, um nicht durch den Abfluss von Kundengeldern in Milliardenhöhe direkt in die Pleite abzustürzen. Beim Neustart in diesem Sommer kam es in der Luftverkehrsbranche zu massiven Problemen und Verspätungen. Wegen fehlender Arbeitskräfte an den Flughäfen und in den Jets führten musste allein die Lufthansa in München und Frankfurt bis zu 7000 Flüge streichen. An den NRW-Flughäfen waren von Mitte Mai bis Mitte Juli mehr als 258.000 Passagiere von Flugausfällen betroffen, wie die Landesregierung in Düsseldorf berichtete. Auch bei der Schlichtungsstelle für den Öffentlichen Personenverkehr (SÖP) sind die Fallzahlen laut "Handelsblatt" um mehr als das Doppelte gestiegen. Betroffene haben in vielen Fällen das Recht auf eine Erstattung des Ticketpreises innerhalb von sieben Tagen sowie auf Entschädigungszahlungen zwischen 250 und 600 Euro. Die EU-Fluggastrichtlinie, die Passagieren diese Rechte einräumt, gilt bereits ab drei Stunden Verspätung. "In der Praxis funktioniert das Recht nicht", kritisiert Helga Zander-Hayat von der Verbraucherzentrale NRW. Eine Sprecherin der Lufthansa sagte dagegen: "Trotz der vielen Flugplanänderungen leisten wir die Erstattungen nahezu vollständig in der vorgegebenen Frist von nur sieben Tagen. Insofern gibt es für diese politische Initiative keinen Anlass." Die Vorkasse sei international und auch in anderen Dienstleistungsbranchen üblich, argumentiert der Branchenverband BDL. "Die Fluggesellschaften erhalten durch die Vorkasse Planungssicherheit und können ihre Flugzeuge optimal auslasten, was positiv für das Klima ist. Ihren Kunden können  ...

# %% [markdown]
# Problem: Ziemlich viele Erdogans...wir brauchen ein Verfahren, um
# unterschiedlichen Schreibweisen dieselbe Entität zuzuordnen.
#
# - **Entity Linking**
#   - spaCy hat sowas, aber man braucht:
#     - eine Knowledge Base
#     - eine Funktion, die plausible Kandidaten aus der KB zieht,
#     - ein ML-Modell, das anhand des lokalen Kontexts den wahrscheinlichsten
#       Kandidaten auswählt
#     - Bisschen viel
#   - Recherche:
#     - [amazon-science/ReFinED: ReFinED is an efficient and accurate entity linking (EL) system.](https://github.com/amazon-science/ReFinED)
#     - [Improving Named Entity Disambiguation using Entity Relatedness within Wikipedia | by Will Seaton | Towards Data Science](https://towardsdatascience.com/improving-named-entity-disambiguation-using-entity-relatedness-within-wikipedia-92f400ee5994)
#     - [Introducing the Kensho Derived Wikimedia Dataset | by Gabriel Altay | Kensho Blog](https://blog.kensho.com/announcing-the-kensho-derived-wikimedia-dataset-5d1197d72bcf)
#     - [Kensho Derived Wikimedia Dataset | Kaggle](https://www.kaggle.com/datasets/kenshoresearch/kensho-derived-wikimedia-data?select=property_aliases.csv)
#     - [kdwd_wikidata_introduction | Kaggle](https://www.kaggle.com/code/kenshoresearch/kdwd-wikidata-introduction)
# - **Naiver Ansatz**
#   - Nur das letzte Wort der Entität
#
# ## Scraping
#
# **Quelle**: https://www.tagesschau.de/archiv?datum=YYYY-MM-DD -> z.B.: https://www.tagesschau.de/archiv?datum=2023-06-22
#
# div.teasergroup:nth-child(2) > div:nth-child(1) > div:nth-child(1) > div:nth-child(2) > div:nth-child(1) > a:nth-child(1)
# html body div.global-wrapper main.content-wrapper.content-wrapper--show-cuts div.layout-container div#content.layout-content.scrolled div.container div.columns.twelve.teasergroup div.columns.twelve div.columns.twelve.m-ten.m-offset-one.l-eight.l-offset-two div.copytext-element-wrapper__vertical-only div.teaser-right.twelve a.teaser-right__link

# %%
def extract_entities(text):
    doc = nlp(text)
    entities = {}
    for ent in doc.ents:
        # if ent.label_ in ["PER"]:
        if ent.label_:
            if ent._.kb_qid:
                entities[ent._.kb_qid] = (
                    ent.text,
                    ent.label_,
                    ent._.kb_qid,
                    ent._.url_wikidata,
                    ent._.nerd_score,
                )
    return entities

# %%
print(df_texts["title"].unique().shape, df_texts.shape)

df_texts.sort_values("url", inplace=True)
df_texts
# Out:
# (14883,) (15123, 6)
#            tstamp                                           title  \
# 12771  1682418239  Neuer Livestream und verbesserter Audio-Player
# 11007  1680256839                                     Quote gegen
# 258    1657270166                 Schock und Trauer über Attentat
# 696    1656799826   Palästinenser übergeben tödliche Kugel an USA
# 1424   1660519926        Kopten nach Brand in Kirche unter Schock
# ...           ...                                             ...
# 9756   1677002967                          Das Universum im Labor
# 11895  1681408814                                   Wie Bären der
# 8435   1673547931      2022 war eines der weltweit wärmsten Jahre
# 13100  1684569237                     Wie geht es den Wildbienen?
# 12406  1683129959                       Eine Datenbank des Lebens
#
#                          date  \
# 12771  25.04.2023 • 12:23 Uhr
# 11007  31.03.2023 • 12:00 Uhr
# 258    08.07.2022 • 10:49 Uhr
# 696    03.07.2022 • 00:10 Uhr
# 1424   15.08.2022 • 01:32 Uhr
# ...                       ...
# 9756   21.02.2023 • 19:09 Uhr
# 11895  13.04.2023 • 20:00 Uhr
# 8435   12.01.2023 • 19:25 Uhr
# 13100  20.05.2023 • 09:53 Uhr
# 12406  03.05.2023 • 18:05 Uhr
#
#                                                shorttext  \
# 12771  Mit dem jüngsten Update der tagesschau-App bie...
# 11007  Seit einem Jahr gilt in Argentiniens Behörden ...
# 258    Das Attentat auf Japans Ex-Ministerpräsidenten...
# 696    Im Fall der im Westjordanland getöteten Journa...
# 1424   Ein Feuer in einer koptischen Kirche hat zahlr...
# ...                                                  ...
# 9756   In Darmstadt wird ein neuer, großer Teilchenbe...
# 11895  Wenn Menschen lange bettlägerig sind, wächst d...
# 8435   Das vergangene Jahr war weltweit das fünft- od...
# 13100  Während die Honigbiene so gut dasteht wie lang...
# 12406  Um die Funktion unseres Körpers besser zu vers...
#
#                                                      url  \
# 12771                                               /app
# 11007                /argentinien-transmenschen-101.html
# 258              /ausland/abe-anschlag-reaktion-101.html
# 696       /ausland/abuakle-kugel-palaestinenser-101.html
# 1424             /ausland/aegypten-kopten-feuer-101.html
# ...                                                  ...
# 9756    /wissen/teilchenbeschleuniger-darmstadt-101.html
# 11895         /wissen/thromboseforschung-baeren-101.html
# 8435   /wissen/weltwetterorganisation-waerme-2022-101...
# 13100                        /wissen/wildbienen-100.html
# 12406                          /wissen/zoonomia-100.html
#
#                                                 fulltext
# 12771   Mit dem jüngsten Update der tagesschau-App bi...
# 11007   Seit einem Jahr gilt in Argentiniens Behörden...
# 258     Das Attentat auf Japans Ex-Ministerpräsidente...
# 696     Im Fall der im Westjordanland getöteten Journ...
# 1424    Ein Feuer in einer koptischen Kirche hat zahl...
# ...                                                  ...
# 9756    In Darmstadt wird ein neuer, großer Teilchenb...
# 11895   Wenn Menschen lange bettlägerig sind, wächst ...
# 8435    Das vergangene Jahr war weltweit das fünft- o...
# 13100   Während die Honigbiene so gut dasteht wie lan...
# 12406   Um die Funktion unseres Körpers besser zu ver...
#
# [15123 rows x 6 columns]

# %%
with open("entities.jsonl", "w", encoding="utf8") as f:
    for text in tqdm(df_texts["fulltext"].values):
        entities = extract_entities(text)
        if entities:
            json.dump({"entities": entities}, f, ensure_ascii=False)
            f.write("\n")

# %% [markdown]
# Der Shit ist lahm, ich brauche mehr Parallelität!

# %%
# cluster = LocalCluster()
# client = Client(cluster)
# client
# Out:
# c:\Users\p\miniconda3\envs\mbb-asud-proto-tagesschau\Lib\site-packages\distributed\node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 56588 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:56590' processes=4 threads=12, memory=15.90 GiB>

# %%
df_text_nrm = pd.DataFrame(df_texts.sample(10).loc[:, "fulltext"].str.normalize("NFKD"))
df_text_nrm
# Out:
#                                                 fulltext
# 9303    Auch nach Tagen sorgt die Aussage von Außenmi...
# 2052    Die USA haben eigenen Angaben nach eine "Anti...
# 9938    In Jerusalem haben Tausende Menschen vor dem ...
# 185     Seit Ausbruch des Ukraine-Kriegs ist Gas knap...
# 10477   Im Kabinett hat eine Nationale Wasserstrategi...
# 9824    Er hat gemahnt, gewarnt, gefleht. Seine Auftr...
# 6670    Die Themenliste des EU-Gipfels war lang und d...
# 14885   Die ukrainische Gegenoffensive hat begonnen u...
# 11004   Russlands Präsident Putin, der vor Chinas St...
# 6652    Besorgnis und Kritik nach der Sperrung mehrer...

# %%
import dask.dataframe as dd
from dask.diagnostics import ProgressBar

def do_extract_entities(df, partition_info: dict):
    with open(f"../out/entities-{partition_info['number']}.jsonl", "w", encoding="utf8") as f:    
        for text in df["fulltext"].values:
            entities = extract_entities(text)
            if entities:
                json.dump({"entities": entities}, f, ensure_ascii=False)
                f.write("\n")

ddf_text = dd.from_pandas(df_texts, chunksize=200)

with ProgressBar():
    ddf_text.map_partitions(do_extract_entities, meta=("entities", "object")).compute()
# Out:
# [########################################] | 100% Completed | 2hr 7ms

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import sys

user_agent = f"Academic Research Python/{sys.version_info[0]}.{sys.version_info[0]}"
endpoint = "https://query.wikidata.org/sparql"
sparql = SPARQLWrapper(endpoint, agent=user_agent, returnFormat=JSON)

sparql.setQuery("""
""")

# %% [markdown]
# ### Entities von Wikidata scrapen
#
# 1. Alle `entities-*.jsonl` zusammenfügen
# 2. Entities in neues Dict, dabei Infos aus der NER beibehalten und Anreicherung durch Wikidata vorbereiten
# 3. Liste aller Entities für Scraper generieren (in jsonl oder so)
# 4. Alle Entities von Wikidata scrapen
#    1. Herausforderung I: Manche Einträge haben kein Label/keine Description -> dann statt dessen Entitätskenner
#    2. Herausforderung II: Manche Einträge leiten auf andere Entitäten weiter -> dann weitergeleitete ID speichern
# 5. Zusammenführen (direkt im Scraper?)

# %%
from pathlib import Path

with open("../out/all-entities.jsonl", mode="w", encoding="utf8") as f_out:
    for entfile in Path("../out/").glob("entities-*.jsonl"):
        with open(entfile, mode="r", encoding="utf8") as f_in:
            f_out.write(f_in.read())

# %%
import jsonlines as jl

catalog = {}
with jl.open("../out/all-entities.jsonl", mode="r") as all_objs:
    for obj in tqdm(all_objs.iter()):
        for key, extract in obj["entities"].items():
            if key not in catalog:
                catalog[key] = {
                    "id": key,
                    "extracts": [extract],
                }
            else:
                catalog[key]["extracts"].append(extract)

# json.dump(catalog, open("../out/catalog.json", mode="w"), indent=4, ensure_ascii=True)

with jl.open("../out/catalog.jsonl", mode="w") as catalog_file:
    for k, v in tqdm(catalog.items()):
        catalog_file.write(v)

# catalog = jl.open("../out/catalog.jsonl", mode="r")
# Out:
# 14957it [00:01, 10660.68it/s]
# 100%|██████████| 36016/36016 [00:00<00:00, 55748.89it/s]
